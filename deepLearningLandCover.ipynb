# %% [markdown]
# <a href="https://colab.research.google.com/github/Brandy5453/LULC_using-deep-learning-/blob/main/deepLearningLandCover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install some packages
# !pip install rasterio
# !pip install earthpy
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 32.2 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7
# Collecting earthpy
#   Downloading earthpy-0.9.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from earthpy) (0.13.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from earthpy) (3.7.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from earthpy) (1.25.2)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (from earthpy) (1.3.10)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from earthpy) (0.19.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from earthpy) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->earthpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->earthpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->earthpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->earthpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->earthpy) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->earthpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->earthpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->earthpy) (2.8.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas->earthpy) (1.9.6)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas->earthpy) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas->earthpy) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas->earthpy) (2.0.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio->earthpy) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->earthpy) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->earthpy) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio->earthpy) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->earthpy) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio->earthpy) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->earthpy) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->earthpy) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->earthpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->earthpy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->earthpy) (2.0.7)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->earthpy) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->earthpy) (3.3)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->earthpy) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->earthpy) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->earthpy) (1.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas->earthpy) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas->earthpy) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas->earthpy) (2024.1)
# Installing collected packages: earthpy
# Successfully installed earthpy-0.9.4

# %%
# Import packages
import pandas as pd
import numpy as np
import keras
from keras import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dense, Dropout, Flatten, Input, GlobalMaxPooling1D
from keras.callbacks import EarlyStopping
from keras import Model
import rasterio
import earthpy.plot as ep
from keras.utils import to_categorical, plot_model, model_to_dot
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors

# %%
# Mount GDRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Parameter
FEATURES = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'EVI', 'NBR', 'NDMI', 'NDWI', 'NDBI', 'NDBaI', 'elevation']
LABEL = ['classvalue']
SPLIT = ['sample']
N_CLASSES = 9
CLASSES = [1, 2, 3, 4, 5]
PALETTE = ['#d62f08', '#586dff', '#50b12d', '#104003', '#736242']
SAMPLE_PATH = '/content/drive/MyDrive/DL/Samples_LC_Jambi_2023.csv'
IMAGE_PATH = '/content/drive/MyDrive/DL/Landsat_Jambi_2023.tif'

# %%
# Load image
image = rasterio.open(IMAGE_PATH)
bandNum = image.count
height = image.height
width = image.width
crs = image.crs
transform = image.transform
shape = (height, width)

image_vis = []
for x in [6, 5, 4]:
  image_vis.append(image.read(x))
image_vis = np.stack(image_vis)

plot_size = (8, 8)
ep.plot_rgb(
  image_vis,
  figsize=plot_size,
  stretch=True,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/earthpy/spatial.py:561: RuntimeWarning: invalid value encountered in cast
#   return (bytedata.clip(low, high) + 0.5).astype("uint8")
# <Axes: >

# %%
# Read sample
samples = pd.read_csv(SAMPLE_PATH)
samples = samples.sample(frac = 1) # Shuffle data
samples
# Out:
#            B1        B2        B3        B4        B5        B6        B7  \
# 503  0.014170  0.028442  0.076952  0.049370  0.349835  0.194873  0.093838
# 483  0.027205  0.045988  0.085642  0.091624  0.292855  0.252512  0.159837
# 549  0.023520  0.033090  0.064550  0.046703  0.325223  0.242943  0.127002
# 781  0.011255  0.018680  0.048641  0.031275  0.391195  0.167359  0.069335
# 449  0.032072  0.044434  0.085945  0.079317  0.353245  0.263842  0.157431
# ..        ...       ...       ...       ...       ...       ...       ...
# 409  0.019973  0.039167  0.087870  0.083030  0.301077  0.233455  0.170425
# 130  0.032444  0.059669  0.107505  0.134194  0.248223  0.279600  0.233455
# 507  0.019202  0.037792  0.080665  0.071755  0.289253  0.224737  0.137590
# 775  0.011447  0.021127  0.057730  0.042220  0.309066  0.177272  0.082975
# 873  0.012327  0.029872  0.072277  0.060645  0.375259  0.228629  0.123194
#
#           EVI       NBR      NDMI      NDWI      NDBI     NDBaI  elevation  \
# 503  0.524285  0.576997  0.284488 -0.639387 -0.284488  0.349953         40
# 483  0.335902  0.293836  0.073973 -0.547461 -0.073973  0.224748         90
# 549  0.513018  0.438322  0.144817 -0.668781 -0.144817  0.313398         76
# 781  0.625406  0.698890  0.400743 -0.778821 -0.400743  0.414137         77
# 449  0.457798  0.383440  0.144878 -0.608620 -0.144878  0.252594         88
# ..        ...       ...       ...       ...       ...       ...        ...
# 409  0.362085  0.277098  0.126508 -0.548165 -0.126508  0.156061         44
# 130  0.177519  0.030658 -0.059447 -0.395577  0.059447  0.089942         77
# 507  0.378562  0.355313  0.125518 -0.563876 -0.125518  0.240521         49
# 775  0.475177  0.576703  0.270992 -0.685220 -0.270992  0.362338        110
# 873  0.519135  0.505695  0.242810 -0.676998 -0.242810  0.299682         74
#
#      classvalue sample
# 503           3  train
# 483           3  train
# 549           3  train
# 781           4   test
# 449           3  train
# ..          ...    ...
# 409           3  train
# 130           1   test
# 507           3  train
# 775           4   test
# 873           5  train
#
# [1042 rows x 16 columns]

# %%
# Split into train and test based on column
train = samples[samples['sample'] == 'train']
test = samples[samples['sample'] == 'test']

# Split between features and label
train_features = train[FEATURES]
train_label = train[LABEL]
test_features = test[FEATURES]
test_label = test[LABEL]

# Function to reshape array input
def reshape_input(array):
  shape = array.shape
  return array.reshape(shape[0], shape[1], 1)

# Convert samples dataframe (pandas) to numpy array
train_input = reshape_input(train_features.to_numpy())
test_input = reshape_input(test_features.to_numpy())

# Also make label data to categorical
train_output = to_categorical(train_label.to_numpy(), N_CLASSES + 1, int)
test_output = to_categorical(test_label.to_numpy(), N_CLASSES + 1, int)

# Show the data shape
print(f'Train features: {train_input.shape}\nTest features: {test_input.shape}\nTrain label: {train_output.shape}\nTest label: {test_output.shape}')
# Out:
# Train features: (819, 14, 1)
# Test features: (223, 14, 1)
# Train label: (819, 10)
# Test label: (223, 10)

# %%
# Make model for our data
# Input shape
train_shape = train_input.shape
input_shape = (train_shape[1], train_shape[2])

# Model parameter
neuron = 64
drop = 0.2
kernel = 2
pool = 2

# Make sequential model
model = Sequential([
  Input(input_shape),
  Conv1D(neuron * 1, kernel, activation='relu'),
  Conv1D(neuron * 1, kernel, activation='relu'),
  MaxPooling1D(pool),
  Dropout(drop),
  Conv1D(neuron * 2, kernel, activation='relu'),
  Conv1D(neuron * 2, kernel, activation='relu'),
  MaxPooling1D(pool),
  Dropout(drop),
  GlobalMaxPooling1D(),
  Dense(neuron * 2, activation='relu'),
  Dropout(drop),
  Dense(neuron * 1, activation='relu'),
  Dropout(drop),
  Dense(N_CLASSES + 1, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 13, 64)            192
#
#  conv1d_1 (Conv1D)           (None, 12, 64)            8256
#
#  max_pooling1d (MaxPooling1  (None, 6, 64)             0
#  D)
#
#  dropout (Dropout)           (None, 6, 64)             0
#
#  conv1d_2 (Conv1D)           (None, 5, 128)            16512
#
#  conv1d_3 (Conv1D)           (None, 4, 128)            32896
#
#  max_pooling1d_1 (MaxPoolin  (None, 2, 128)            0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 2, 128)            0
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 83274 (325.29 KB)
# Trainable params: 83274 (325.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model

# Compline the model
model.compile(
    optimizer='Adam',
    loss='CategoricalCrossentropy',
    metrics=['accuracy']
)

# Create callback to stop training if loss not decreasing
stop = EarlyStopping(
    monitor='loss',
    patience=5
)

# Fit the model
result = model.fit(
    x=train_input, y=train_output,
    validation_data=(test_input, test_output),
    batch_size=1024,
    callbacks=[stop],
    epochs=100,
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 8s 8s/step - loss: 2.5808 - accuracy: 0.0366 - val_loss: 2.2355 - val_accuracy: 0.2691
# Epoch 2/100
# 1/1 [==============================] - 0s 41ms/step - loss: 2.2972 - accuracy: 0.1575 - val_loss: 2.1191 - val_accuracy: 0.2691
# Epoch 3/100
# 1/1 [==============================] - 0s 37ms/step - loss: 2.1636 - accuracy: 0.2552 - val_loss: 2.0554 - val_accuracy: 0.2691
# Epoch 4/100
# 1/1 [==============================] - 0s 37ms/step - loss: 2.0877 - accuracy: 0.3126 - val_loss: 2.0077 - val_accuracy: 0.2691
# Epoch 5/100
# 1/1 [==============================] - 0s 36ms/step - loss: 2.0499 - accuracy: 0.2759 - val_loss: 1.9657 - val_accuracy: 0.2691
# Epoch 6/100
# 1/1 [==============================] - 0s 37ms/step - loss: 2.0138 - accuracy: 0.2759 - val_loss: 1.9211 - val_accuracy: 0.2691
# Epoch 7/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.9757 - accuracy: 0.2650 - val_loss: 1.8767 - val_accuracy: 0.2691
# Epoch 8/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.9459 - accuracy: 0.2821 - val_loss: 1.8346 - val_accuracy: 0.2691
# Epoch 9/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.8825 - accuracy: 0.2527 - val_loss: 1.7955 - val_accuracy: 0.2691
# Epoch 10/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.8537 - accuracy: 0.2601 - val_loss: 1.7631 - val_accuracy: 0.2691
# Epoch 11/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.8205 - accuracy: 0.2772 - val_loss: 1.7370 - val_accuracy: 0.2691
# Epoch 12/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.8469 - accuracy: 0.2650 - val_loss: 1.7126 - val_accuracy: 0.2691
# Epoch 13/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.7848 - accuracy: 0.2784 - val_loss: 1.6854 - val_accuracy: 0.2691
# Epoch 14/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.7527 - accuracy: 0.2723 - val_loss: 1.6577 - val_accuracy: 0.2691
# Epoch 15/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.7692 - accuracy: 0.2418 - val_loss: 1.6369 - val_accuracy: 0.2691
# Epoch 16/100
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7837 - accuracy: 0.2527 - val_loss: 1.6238 - val_accuracy: 0.2691
# Epoch 17/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1
100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0455 - accuracy: 0.5360 - val_loss: 0.8586 - val_accuracy: 0.6457
# Epoch 83/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0391 - accuracy: 0.5580 - val_loss: 0.8600 - val_accuracy: 0.6502
# Epoch 84/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0450 - accuracy: 0.5482 - val_loss: 0.8621 - val_accuracy: 0.6547
# Epoch 85/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0284 - accuracy: 0.5641 - val_loss: 0.8582 - val_accuracy: 0.6726
# Epoch 86/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0506 - accuracy: 0.5421 - val_loss: 0.8394 - val_accuracy: 0.6682
# Epoch 87/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.9976 - accuracy: 0.5812 - val_loss: 0.8313 - val_accuracy: 0.6637
# Epoch 88/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0123 - accuracy: 0.5604 - val_loss: 0.8308 - val_accuracy: 0.6726
# Epoch 89/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.9948 - accuracy: 0.5788 - val_loss: 0.8440 - val_accuracy: 0.6682
# Epoch 90/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0055 - accuracy: 0.5824 - val_loss: 0.8292 - val_accuracy: 0.6682
# Epoch 91/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9776 - accuracy: 0.5775 - val_loss: 0.8119 - val_accuracy: 0.6637
# Epoch 92/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9838 - accuracy: 0.5849 - val_loss: 0.8076 - val_accuracy: 0.6592
# Epoch 93/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9780 - accuracy: 0.5873 - val_loss: 0.8124 - val_accuracy: 0.6771
# Epoch 94/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9851 - accuracy: 0.5519 - val_loss: 0.8128 - val_accuracy: 0.6682
# Epoch 95/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9498 - accuracy: 0.6007 - val_loss: 0.7958 - val_accuracy: 0.6726
# Epoch 96/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9603 - accuracy: 0.6105 - val_loss: 0.7862 - val_accuracy: 0.6726
# Epoch 97/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.9822 - accuracy: 0.5690 - val_loss: 0.7841 - val_accuracy: 0.6771
# Epoch 98/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.9345 - accuracy: 0.5800 - val_loss: 0.7929 - val_accuracy: 0.6771
# Epoch 99/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.9550 - accuracy: 0.5971 - val_loss: 0.8016 - val_accuracy: 0.6771
# Epoch 100/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9351 - accuracy: 0.6178 - val_loss: 0.8028 - val_accuracy: 0.6682

# %%
# Show history
history = pd.DataFrame(result.history)

plt.figure(figsize = (10, 8))
plt.plot(range(len(history['accuracy'].values.tolist())), history['accuracy'].values.tolist(), label = 'Train_Accuracy')
plt.plot(range(len(history['loss'].values.tolist())), history['loss'].values.tolist(), label = 'Train_Loss')
plt.plot(range(len(history['val_accuracy'].values.tolist())), history['val_accuracy'].values.tolist(), label = 'Test_Accuracy')
plt.plot(range(len(history['val_loss'].values.tolist())), history['val_loss'].values.tolist(), label = 'Test_Loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Predict test data
prediction = np.argmax(model.predict(test_input), 1).flatten()
label = np.argmax(test_output, 1).flatten()

# Confusion matrix
cm = confusion_matrix(label, prediction, normalize='true')
cm = ConfusionMatrixDisplay(cm)
cm.plot()

# Classification report
print(classification_report(label, prediction))
# Out:
# 7/7 [==============================] - 0s 27ms/step
#               precision    recall  f1-score   support
#
#            1       0.66      1.00      0.79        25
#            2       0.76      0.76      0.76        34
#            3       0.52      0.85      0.65        60
#            4       0.97      0.67      0.79        42
#            5       0.79      0.31      0.44        62
#
#     accuracy                           0.67       223
#    macro avg       0.74      0.72      0.69       223
# weighted avg       0.73      0.67      0.65       223

# %%
# Predict image using the model
image_input = []
for x in range(14):
  image_input.append(image.read(x + 1))
image_input = reshape_input(np.stack(image_input).reshape(14, -1).T)

# Predict
prediction = model.predict(image_input, batch_size=4096*20)
prediction = np.argmax(prediction, 1)
prediction = prediction.reshape(shape[0], shape[1])

# Visualize
cmap, norm = from_levels_and_colors(CLASSES, PALETTE, extend='max')
ep.plot_bands(prediction, cmap=cmap, norm=norm, figsize=plot_size)
# Out:
# 4/4 [==============================] - 2s 474ms/step
# <Axes: >

# %%
# Save file to drive
save_location = '/content/drive/MyDrive/DL/'
name = 'LC_Jambi_2023.tif'
location = save_location + name

new_dataset = rasterio.open(
      location,
      mode='w', driver='GTiff',
      height = prediction.shape[0], width = prediction.shape[1],
      count=1, dtype=str(prediction.dtype),
      crs=crs,
      transform=transform
)
new_dataset.write(prediction, 1);
new_dataset.close()
